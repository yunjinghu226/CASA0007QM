# %% [markdown]
# # Workbook 6.0 - Pandas Dataframes Recap

# %% [markdown]
# Pandas is a package that allows you to work with databases in Python:

# %%
import pandas as pd
import numpy as np
import random as rn

# %% [markdown]
# The basic object in Pandas is the **Dataframe** (basically a table).
#
# There are various ways to create a dataframe, but the simplest is to use dictionaries to define the columns:

# %%
tutors          = ['Dennett','Kandt','Arcaute','Wise']
modules         = ['BENVGSA3','BENVGSC1','BENVGSC5','BENVGACH']
student_numbers = [rn.randint(20,90) for i in range(4)]
is_optional     = [False,False,False,True]
terms           = [1,1,2,1]

casa_modules = pd.DataFrame({'tutor' : tutors,
                             'module' : modules,
                             'num_students' : student_numbers,
                             'is_optional' : is_optional,
                             'term' : terms})

casa_modules
# Out:
#    is_optional    module  num_students  term    tutor
# 0        False  BENVGSA3            89     1  Dennett
# 1        False  BENVGSC1            59     1    Kandt
# 2        False  BENVGSC5            32     2  Arcaute
# 3         True  BENVGACH            86     1     Wise

# %% [markdown]
# Most of the time though, we will want to import data from elsewhere to use in Python. For example, let's work with the coursework data ('coursework_1_data_2017.csv'):

# %%
df = pd.read_csv('coursework_1_data_2017.csv')

# %% [markdown]
# Once you have imported the data, you will want to get an idea of what it looks like:

# %%
df.head()
# Out:
#            local_authority_area  2008_KSI  2009_KSI  2010_KSI  2008_pop  \
# 0          Barking and Dagenham        63        64        56    171500
# 1                        Barnet       136       128       127    338100
# 2                      Barnsley       112       116       100    225200
# 3  Bath and North East Somerset        34        20        20    177400
# 4                       Bedford        80        86        65    157100
#
#    2009_pop  2010_pop  Total_Budget  Cyclist_Safety  Child_Safety  \
# 0    175600    179500        139000           21000         22000
# 1    343100    347200        220000           50000         17000
# 2    226300    227000        160000           41000         45000
# 3    177700    177200        161000           33000         42000
# 4    158000    158200        130000           37000         52000
#
#    Motorcycle_Safety  Drink_Drive_Campaigns  Promote_Cycling  \
# 0              18000                  41000            18000
# 1              23000                  74000            30000
# 2               5000                  26000            29000
# 3              19000                  50000            10000
# 4              17000                   8000             3000
#
#    Promote_Car_Sharing  local_authority_type
# 0                19000        london_borough
# 1                26000        london_borough
# 2                14000  metropolitan_borough
# 3                 7000     unitary_authority
# 4                13000     unitary_authority

# %% [markdown]
# You will notice that there is a column of numbers on the left hand side that do not appear in the file. These are the row labels (the **index** of the dataframe).
#
# Since our rows represent local authority areas, we perhaps want to use these as our row labels instead:

# %%
df = df.set_index('local_authority_area')
df.head()
# Out:
#                               2008_KSI  2009_KSI  2010_KSI  2008_pop  \
# local_authority_area
# Barking and Dagenham                63        64        56    171500
# Barnet                             136       128       127    338100
# Barnsley                           112       116       100    225200
# Bath and North East Somerset        34        20        20    177400
# Bedford                             80        86        65    157100
#
#                               2009_pop  2010_pop  Total_Budget  \
# local_authority_area
# Barking and Dagenham            175600    179500        139000
# Barnet                          343100    347200        220000
# Barnsley                        226300    227000        160000
# Bath and North East Somerset    177700    177200        161000
# Bedford                         158000    158200        130000
#
#                               Cyclist_Safety  Child_Safety  Motorcycle_Safety  \
# local_authority_area
# Barking and Dagenham                   21000         22000              18000
# Barnet                                 50000         17000              23000
# Barnsley                               41000         45000               5000
# Bath and North East Somerset           33000         42000              19000
# Bedford                                37000         52000              17000
#
#                               Drink_Drive_Campaigns  Promote_Cycling  \
# local_authority_area
# Barking and Dagenham                          41000            18000
# Barnet                                        74000            30000
# Barnsley                                      26000            29000
# Bath and North East Somerset                  50000            10000
# Bedford                                        8000             3000
#
#                               Promote_Car_Sharing  local_authority_type
# local_authority_area
# Barking and Dagenham                        19000        london_borough
# Barnet                                      26000        london_borough
# Barnsley                                    14000  metropolitan_borough
# Bath and North East Somerset                 7000     unitary_authority
# Bedford                                     13000     unitary_authority

# %% [markdown]
# If you want just the column headers, just the index, or just the body data:

# %%
df.columns
# Out:
# Index(['2008_KSI', '2009_KSI', '2010_KSI', '2008_pop', '2009_pop', '2010_pop',
#        'Total_Budget', 'Cyclist_Safety', 'Child_Safety', 'Motorcycle_Safety',
#        'Drink_Drive_Campaigns', 'Promote_Cycling', 'Promote_Car_Sharing',
#        'local_authority_type'],
#       dtype='object')

# %%
df.index
# Out:
# Index(['Barking and Dagenham', 'Barnet', 'Barnsley',
#        'Bath and North East Somerset', 'Bedford', 'Bexley', 'Birmingham',
#        'Blackburn with Darwen', 'Blackpool', 'Bolton',
#        ...
#        'West Sussex', 'Westminster', 'Wigan', 'Wiltshire',
#        'Windsor and Maidenhead', 'Wirral', 'Wokingham', 'Wolverhampton',
#        'Worcestershire', 'York'],
#       dtype='object', name='local_authority_area', length=151)

# %%
df.values
# Out:
# array([[63, 64, 56, ..., 18000, 19000, 'london_borough'],
#        [136, 128, 127, ..., 30000, 26000, 'london_borough'],
#        [112, 116, 100, ..., 29000, 14000, 'metropolitan_borough'],
#        ...,
#        [79, 80, 70, ..., 50000, 28000, 'metropolitan_borough'],
#        [249, 250, 227, ..., 67000, 30000, 'non_metropolitan_county'],
#        [95, 92, 93, ..., 37000, 19000, 'unitary_authority']], dtype=object)

# %% [markdown]
# Slicing and indexing works a little differently in pandas. You can choose between a couple of different methods, depending on whether you want to use the row and column labels (.loc[ ]) or numerical values (.iloc[ ]) to select data:

# %%
df.loc[['Barnsley','City of London'],['2008_KSI']] # Returns a dataframe
# Out:
#                       2008_KSI
# local_authority_area
# Barnsley                   112
# City of London              51

# %%
df.iloc[0:3,5:8] # Returns a dataframe
# Out:
#                       2010_pop  Total_Budget  Cyclist_Safety
# local_authority_area
# Barking and Dagenham    179500        139000           21000
# Barnet                  347200        220000           50000
# Barnsley                227000        160000           41000

# %%
df.loc['Barnsley','2008_KSI'] # Returns an entry
# Out:
# 112

# %%
df.iloc[17,13] # Returns an entry
# Out:
# 'non_metropolitan_county'

# %% [markdown]
# There is a nice method to give you some summary statistics of your dataframe (note that the statistics themselves are returned to you as a dataframe):

# %%
summary_stats = df.describe()
summary_stats
# Out:
#          2008_KSI    2009_KSI    2010_KSI      2008_pop      2009_pop  \
# count  151.000000  151.000000  151.000000  1.510000e+02  1.510000e+02
# mean   161.350993  157.026490  145.403974  3.408119e+05  3.430954e+05
# std    144.221367  143.273489  135.096666  2.597462e+05  2.613104e+05
# min     21.000000   14.000000   10.000000  1.130000e+04  1.150000e+04
# 25%     71.500000   65.000000   61.500000  1.890000e+05  1.909500e+05
# 50%    102.000000   99.000000   94.000000  2.529000e+05  2.539000e+05
# 75%    195.500000  191.500000  164.500000  3.829000e+05  3.833500e+05
# max    801.000000  773.000000  752.000000  1.401700e+06  1.411100e+06
#
#            2010_pop  Total_Budget  Cyclist_Safety   Child_Safety  \
# count  1.510000e+02  1.510000e+02      151.000000     151.000000
# mean   3.454225e+05  2.720861e+05    59761.589404   68880.794702
# std    2.628719e+05  2.100151e+05    53941.784498   62069.093453
# min    1.170000e+04  5.000000e+04     4000.000000    4000.000000
# 25%    1.920000e+05  1.405000e+05    26000.000000   32000.000000
# 50%    2.548000e+05  2.000000e+05    42000.000000   48000.000000
# 75%    3.836500e+05  3.045000e+05    70000.000000   79000.000000
# max    1.427500e+06  1.170000e+06   297000.000000  333000.000000
#
#        Motorcycle_Safety  Drink_Drive_Campaigns  Promote_Cycling  \
# count         151.000000             151.000000       151.000000
# mean        25278.145695           63033.112583     33185.430464
# std         22798.584442           55015.563521     29908.171453
# min          1000.000000            3000.000000      2000.000000
# 25%         12500.000000           32000.000000     14000.000000
# 50%         18000.000000           45000.000000     25000.000000
# 75%         27000.000000           70500.000000     40500.000000
# max        130000.000000          340000.000000    203000.000000
#
#        Promote_Car_Sharing
# count           151.000000
# mean          21947.019868
# std           19818.102189
# min            1000.000000
# 25%            9000.000000
# 50%           16000.000000
# 75%           27500.000000
# max           99000.000000

# %% [markdown]
# One area was missing from the coursework data. Road deaths and serious injuries for Heathrow Airport were recorded separately from the London borough of Hillingdon, where Heathrow is located.
#
# The .loc method can also be used to add an extra row to our data:

# %%
extra_row = ['Heathrow Airport',5,2,3,0,0,0,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,'other_london']
df.loc[extra_row[0]] = extra_row[1:]
df.tail()
# Out:
#                       2008_KSI  2009_KSI  2010_KSI  2008_pop  2009_pop  \
# local_authority_area
# Wokingham                   46        44        36    159700    161900
# Wolverhampton               79        80        70    238100    238500
# Worcestershire             249       250       227    555300    556500
# York                        95        92        93    194900    198800
# Heathrow Airport             5         2         3         0         0
#
#                       2010_pop  Total_Budget  Cyclist_Safety  Child_Safety  \
# local_authority_area
# Wokingham               164200      109000.0         20000.0       41000.0
# Wolverhampton           238500      201000.0         18000.0       27000.0
# Worcestershire          559300      470000.0        128000.0      112000.0
# York                    203100      140000.0          5000.0       39000.0
# Heathrow Airport             0           NaN             NaN           NaN
#
#                       Motorcycle_Safety  Drink_Drive_Campaigns  \
# local_authority_area
# Wokingham                       13000.0                19000.0
# Wolverhampton                   23000.0                55000.0
# Worcestershire                  57000.0                76000.0
# York                             8000.0                32000.0
# Heathrow Airport                    NaN                    NaN
#
#                       Promote_Cycling  Promote_Car_Sharing  \
# local_authority_area
# Wokingham                     10000.0               6000.0
# Wolverhampton                 50000.0              28000.0
# Worcestershire                67000.0              30000.0
# York                          37000.0              19000.0
# Heathrow Airport                  NaN                  NaN
#
#                          local_authority_type
# local_authority_area
# Wokingham                   unitary_authority
# Wolverhampton            metropolitan_borough
# Worcestershire        non_metropolitan_county
# York                        unitary_authority
# Heathrow Airport                 other_london

# %% [markdown]
# As we can see, Heathrow has been added at the bottom of the table, but perhaps we want to resort the index alphabetically:

# %%
df = df.sort_index(axis=0,ascending=True)
df.tail()
# Out:
#                       2008_KSI  2009_KSI  2010_KSI  2008_pop  2009_pop  \
# local_authority_area
# Wirral                     145       137       129    308500    308500
# Wokingham                   46        44        36    159700    161900
# Wolverhampton               79        80        70    238100    238500
# Worcestershire             249       250       227    555300    556500
# York                        95        92        93    194900    198800
#
#                       2010_pop  Total_Budget  Cyclist_Safety  Child_Safety  \
# local_authority_area
# Wirral                  308200      209000.0         69000.0       47000.0
# Wokingham               164200      109000.0         20000.0       41000.0
# Wolverhampton           238500      201000.0         18000.0       27000.0
# Worcestershire          559300      470000.0        128000.0      112000.0
# York                    203100      140000.0          5000.0       39000.0
#
#                       Motorcycle_Safety  Drink_Drive_Campaigns  \
# local_authority_area
# Wirral                          30000.0                41000.0
# Wokingham                       13000.0                19000.0
# Wolverhampton                   23000.0                55000.0
# Worcestershire                  57000.0                76000.0
# York                             8000.0                32000.0
#
#                       Promote_Cycling  Promote_Car_Sharing  \
# local_authority_area
# Wirral                        14000.0               8000.0
# Wokingham                     10000.0               6000.0
# Wolverhampton                 50000.0              28000.0
# Worcestershire                67000.0              30000.0
# York                          37000.0              19000.0
#
#                          local_authority_type
# local_authority_area
# Wirral                   metropolitan_borough
# Wokingham                   unitary_authority
# Wolverhampton            metropolitan_borough
# Worcestershire        non_metropolitan_county
# York                        unitary_authority

# %% [markdown]
# Or perhaps we want to sort everything by the total budgets:

# %%
df = df.sort_values(by="Total_Budget",ascending=True)
df.head()
# Out:
#                       2008_KSI  2009_KSI  2010_KSI  2008_pop  2009_pop  \
# local_authority_area
# City of London              51        52        48     11300     11500
# Rutland                     30        25        31     38100     38400
# Darlington                  34        27        27    100100    100400
# Hartlepool                  29        24        21     90800     90900
# Bracknell Forest            21        14        10    114000    115100
#
#                       2010_pop  Total_Budget  Cyclist_Safety  Child_Safety  \
# local_authority_area
# City of London           11700       50000.0         12000.0        9000.0
# Rutland                  38400       51000.0         17000.0        5000.0
# Darlington              100500       79000.0         18000.0       33000.0
# Hartlepool               91300       89000.0         37000.0       14000.0
# Bracknell Forest        116200       90000.0         35000.0       25000.0
#
#                       Motorcycle_Safety  Drink_Drive_Campaigns  \
# local_authority_area
# City of London                   6000.0                20000.0
# Rutland                          8000.0                14000.0
# Darlington                       3000.0                12000.0
# Hartlepool                       7000.0                17000.0
# Bracknell Forest                 9000.0                 4000.0
#
#                       Promote_Cycling  Promote_Car_Sharing  \
# local_authority_area
# City of London                 2000.0               1000.0
# Rutland                        5000.0               2000.0
# Darlington                    10000.0               3000.0
# Hartlepool                     7000.0               7000.0
# Bracknell Forest              13000.0               4000.0
#
#                      local_authority_type
# local_authority_area
# City of London               other_london
# Rutland                 unitary_authority
# Darlington              unitary_authority
# Hartlepool              unitary_authority
# Bracknell Forest        unitary_authority

# %% [markdown]
# All the manipulations that you might have wanted to do for the previous piece of coursework can be done pretty easily in pandas. For example, suppose you want to add a column to the dataframe for 2008_KSI per hundred thousand people:

# %%
df['2008_KSI_pht'] = 100000 * df["2008_KSI"] / df["2008_pop"]
df.head()
# Out:
#                       2008_KSI  2009_KSI  2010_KSI  2008_pop  2009_pop  \
# local_authority_area
# City of London              51        52        48     11300     11500
# Rutland                     30        25        31     38100     38400
# Darlington                  34        27        27    100100    100400
# Hartlepool                  29        24        21     90800     90900
# Bracknell Forest            21        14        10    114000    115100
#
#                       2010_pop  Total_Budget  Cyclist_Safety  Child_Safety  \
# local_authority_area
# City of London           11700       50000.0         12000.0        9000.0
# Rutland                  38400       51000.0         17000.0        5000.0
# Darlington              100500       79000.0         18000.0       33000.0
# Hartlepool               91300       89000.0         37000.0       14000.0
# Bracknell Forest        116200       90000.0         35000.0       25000.0
#
#                       Motorcycle_Safety  Drink_Drive_Campaigns  \
# local_authority_area
# City of London                   6000.0                20000.0
# Rutland                          8000.0                14000.0
# Darlington                       3000.0                12000.0
# Hartlepool                       7000.0                17000.0
# Bracknell Forest                 9000.0                 4000.0
#
#                       Promote_Cycling  Promote_Car_Sharing  \
# local_authority_area
# City of London                 2000.0               1000.0
# Rutland                        5000.0               2000.0
# Darlington                    10000.0               3000.0
# Hartlepool                     7000.0               7000.0
# Bracknell Forest              13000.0               4000.0
#
#                      local_authority_type  2008_KSI_pht
# local_authority_area
# City of London               other_london    451.327434
# Rutland                 unitary_authority     78.740157
# Darlington              unitary_authority     33.966034
# Hartlepool              unitary_authority     31.938326
# Bracknell Forest        unitary_authority     18.421053

# %% [markdown]
# One of the most useful things to do with a dataframe is to search it for rows that fulfil particular conditions. This is always done by creating a Boolean series and using this to index the dataframe.
#
# For example, select the rows relating to areas in London:

# %%
bool_series = df['local_authority_type'].isin(['london_borough','other_london'])
bool_series
# Out:
# local_authority_area
# City of London              True
# Rutland                    False
# Darlington                 False
# Hartlepool                 False
# Bracknell Forest           False
# Blackburn with Darwen      False
# Blackpool                  False
# Halton                     False
# Poole                      False
# Middlesbrough              False
# Wokingham                  False
# North East Lincolnshire    False
# Reading                    False
# Slough                     False
# Telford and Wrekin         False
# Windsor and Maidenhead     False
# Southend on Sea            False
# Redcar and Cleveland       False
# Thurrock                   False
# Herefordshire              False
# Knowsley                   False
# Isle of Wight              False
# Hammersmith and Fulham      True
# Torbay                     False
# Kensington and Chelsea      True
# Bournemouth                False
# Richmond-upon-Thames        True
# Peterborough               False
# Bedford                    False
# South Tyneside             False
#                            ...
# Sheffield                  False
# Manchester                 False
# Somerset                   False
# Warwickshire               False
# East Sussex                False
# Bradford                   False
# Leicestershire             False
# Gloucestershire            False
# Worcestershire             False
# North Yorkshire            False
# Lincolnshire               False
# Nottinghamshire            False
# Leeds                      False
# Cambridgeshire             False
# Suffolk                    False
# Oxfordshire                False
# Staffordshire              False
# Derbyshire                 False
# Devon                      False
# Northamptonshire           False
# Norfolk                    False
# West Sussex                False
# Lancashire                 False
# Birmingham                 False
# Hertfordshire              False
# Surrey                     False
# Essex                      False
# Hampshire                  False
# Kent                       False
# Heathrow Airport            True
# Name: local_authority_type, Length: 152, dtype: bool

# %%
df3 = df[bool_series]
df3.head()
# Out:
#                         2008_KSI  2009_KSI  2010_KSI  2008_pop  2009_pop  \
# local_authority_area
# City of London                51        52        48     11300     11500
# Hammersmith and Fulham        94        89        89    168600    169700
# Kensington and Chelsea       113       102        99    171100    169900
# Richmond-upon-Thames          64        64        62    187200    189000
# Kingston-upon-Thames          65        65        59    164600    166700
#
#                         2010_pop  Total_Budget  Cyclist_Safety  Child_Safety  \
# local_authority_area
# City of London             11700       50000.0         12000.0        9000.0
# Hammersmith and Fulham    170300      121000.0         28000.0       26000.0
# Kensington and Chelsea    167900      130000.0         33000.0       42000.0
# Richmond-upon-Thames      190500      130000.0         24000.0       39000.0
# Kingston-upon-Thames      168900      139000.0         32000.0       39000.0
#
#                         Motorcycle_Safety  Drink_Drive_Campaigns  \
# local_authority_area
# City of London                     6000.0                20000.0
# Hammersmith and Fulham            13000.0                36000.0
# Kensington and Chelsea            10000.0                20000.0
# Richmond-upon-Thames              16000.0                29000.0
# Kingston-upon-Thames              13000.0                21000.0
#
#                         Promote_Cycling  Promote_Car_Sharing  \
# local_authority_area
# City of London                   2000.0               1000.0
# Hammersmith and Fulham          14000.0               4000.0
# Kensington and Chelsea          19000.0               6000.0
# Richmond-upon-Thames            12000.0              10000.0
# Kingston-upon-Thames            28000.0               6000.0
#
#                        local_authority_type  2008_KSI_pht
# local_authority_area
# City of London                 other_london    451.327434
# Hammersmith and Fulham       london_borough     55.753262
# Kensington and Chelsea       london_borough     66.043250
# Richmond-upon-Thames         london_borough     34.188034
# Kingston-upon-Thames         london_borough     39.489672

# %% [markdown]
# How about all the unitary authorities with more than 70 KSI in 2010:

# %%
bool_series = (df['2010_KSI'] > 70) & (df['local_authority_type'] == 'unitary_authority')
df4 = df[bool_series]
df4.head()
# Out:
#                          2008_KSI  2009_KSI  2010_KSI  2008_pop  2009_pop  \
# local_authority_area
# North East Lincolnshire       102        99        97    157200    157100
# Herefordshire                  93        91        85    179100    179100
# Isle of Wight                  98        89        91    140200    140200
# Peterborough                  101        98        91    169800    171200
# York                           95        92        93    194900    198800
#
#                          2010_pop  Total_Budget  Cyclist_Safety  Child_Safety  \
# local_authority_area
# North East Lincolnshire    157300      110000.0         25000.0       14000.0
# Herefordshire              179400      120000.0          4000.0       51000.0
# Isle of Wight              140900      120000.0         24000.0       33000.0
# Peterborough               173200      130000.0         18000.0       53000.0
# York                       203100      140000.0          5000.0       39000.0
#
#                          Motorcycle_Safety  Drink_Drive_Campaigns  \
# local_authority_area
# North East Lincolnshire             7000.0                32000.0
# Herefordshire                      13000.0                42000.0
# Isle of Wight                       9000.0                24000.0
# Peterborough                       11000.0                22000.0
# York                                8000.0                32000.0
#
#                          Promote_Cycling  Promote_Car_Sharing  \
# local_authority_area
# North East Lincolnshire          25000.0               7000.0
# Herefordshire                     6000.0               4000.0
# Isle of Wight                    22000.0               8000.0
# Peterborough                     19000.0               7000.0
# York                             37000.0              19000.0
#
#                         local_authority_type  2008_KSI_pht
# local_authority_area
# North East Lincolnshire    unitary_authority     64.885496
# Herefordshire              unitary_authority     51.926298
# Isle of Wight              unitary_authority     69.900143
# Peterborough               unitary_authority     59.481743
# York                       unitary_authority     48.742945

# %% [markdown]
# Finally, we notice that the data for Heathrow is incomplete. No information is available for how much road safety budget was spent there (probably none). There are two ways we could deal with this:
#
# By dropping rows with missing data (NaN)...

# %%
df.dropna(how='any')
# Out:
#                          2008_KSI  2009_KSI  2010_KSI  2008_pop  2009_pop  \
# local_authority_area
# City of London                 51        52        48     11300     11500
# Rutland                        30        25        31     38100     38400
# Darlington                     34        27        27    100100    100400
# Hartlepool                     29        24        21     90800     90900
# Bracknell Forest               21        14        10    114000    115100
# Blackburn with Darwen          66        66        63    139400    139900
# Blackpool                      62        57        52    140600    140000
# Halton                         59        60        55    118500    118700
# Poole                          63        64        55    140700    141200
# Middlesbrough                  47        44        40    140100    140500
# Wokingham                      46        44        36    159700    161900
# North East Lincolnshire       102        99        97    157200    157100
# Reading                        46        41        39    149200    151800
# Slough                         57        57        49    125800    128400
# Telford and Wrekin             42        39        41    161700    162300
# Windsor and Maidenhead         68        60        61    141700    143800
# Southend on Sea                61        58        51    163100    164200
# Redcar and Cleveland           58        44        46    137800    137500
# Thurrock                       76        66        65    155200    157200
# Herefordshire                  93        91        85    179100    179100
# Knowsley                       57        56        52    149700    149400
# Isle of Wight                  98        89        91    140200    140200
# Hammersmith and Fulham         94        89        89    168600    169700
# Torbay                         36        25        23    134000    134000
# Kensington and Chelsea        113       102        99    171100    169900
# Bournemouth                    80        65        64    164600    164900
# Richmond-upon-Thames           64        64        62    187200    189000
# Peterborough                  101        98        91    169800    171200
# Bedford                        80        86        65    157100    158000
# South Tyneside                 41        40        30    151400    152400
# ...                           ...       ...       ...       ...       ...
# Cornwall                      209       203       160    529200    531100
# Sheffield                     211       180       166    539800    547000
# Manchester                    190       193       164    473200    483800
# Somerset                      274       255       243    524200    523500
# Warwickshire                  348       345       335    533200    535100
# East Sussex                   398       397       382    511100    512100
# Bradford                      274       229       231    501400    506800
# Leicestershire                253       239       235    641500    644700
# Gloucestershire               259       262       249    586200    589100
# Worcestershire                249       250       227    555300    556500
# North Yorkshire               536       533       528    593500    597700
# Lincolnshire                  337       320       321    695600    697900
# Nottinghamshire               480       445       446    773300    776600
# Leeds                         371       363       339    779300    787700
# Cambridgeshire                372       369       361    600600    607000
# Suffolk                       372       379       330    710600    714000
# Oxfordshire                   343       342       320    635500    640300
# Staffordshire                 286       289       255    827000    828700
# Derbyshire                    425       437       395    758100    760200
# Devon                         268       267       259    746800    747400
# Northamptonshire              435       440       398    679200    683800
# Norfolk                       388       383       366    847300    853400
# West Sussex                   485       499       434    788600    792900
# Lancashire                    801       773       752   1165100   1165800
# Birmingham                    430       444       372   1019200   1028700
# Hertfordshire                 459       448       409   1083900   1095500
# Surrey                        528       540       485   1100700   1113100
# Essex                         706       693       649   1387500   1399000
# Hampshire                     587       595       557   1283600   1289400
# Kent                          627       569       546   1401700   1411100
#
#                          2010_pop  Total_Budget  Cyclist_Safety  Child_Safety  \
# local_authority_area
# City of London              11700       50000.0         12000.0        9000.0
# Rutland                     38400       51000.0         17000.0        5000.0
# Darlington                 100500       79000.0         18000.0       33000.0
# Hartlepool                  91300       89000.0         37000.0       14000.0
# Bracknell Forest           116200       90000.0         35000.0       25000.0
# Blackburn with Darwen      140100       91000.0         15000.0       16000.0
# Blackpool                  138800       99000.0         24000.0       19000.0
# Halton                     119000       99000.0         31000.0       20000.0
# Poole                      141800      100000.0         16000.0       20000.0
# Middlesbrough              141500      101000.0         19000.0       33000.0
# Wokingham                  164200      109000.0         20000.0       41000.0
# North East Lincolnshire    157300      110000.0         25000.0       14000.0
# Reading                    154400      110000.0         33000.0       30000.0
# Slough                     130600      110000.0         15000.0       15000.0
# Telford and Wrekin         162600      110000.0         14000.0        4000.0
# Windsor and Maidenhead     145800      110000.0         33000.0       37000.0
# Southend on Sea            165700      119000.0         26000.0       41000.0
# Redcar and Cleveland       136800      119000.0         40000.0       29000.0
# Thurrock                   159400      120000.0         21000.0       36000.0
# Herefordshire              179400      120000.0          4000.0       51000.0
# Knowsley                   149000      120000.0         17000.0       33000.0
# Isle of Wight              140900      120000.0         24000.0       33000.0
# Hammersmith and Fulham     170300      121000.0         28000.0       26000.0
# Torbay                     133800      121000.0         32000.0       32000.0
# Kensington and Chelsea     167900      130000.0         33000.0       42000.0
# Bournemouth                165500      130000.0         31000.0       30000.0
# Richmond-upon-Thames       190500      130000.0         24000.0       39000.0
# Peterborough               173200      130000.0         18000.0       53000.0
# Bedford                    158200      130000.0         37000.0       52000.0
# South Tyneside             153000      130000.0         16000.0       47000.0
# ...                           ...           ...             ...           ...
# Cornwall                   533600      411000.0        139000.0      145000.0
# Sheffield                  555100      430000.0        130000.0      131000.0
# Manchester                 496600      439000.0        149000.0       69000.0
# Somerset                   525300      439000.0        131000.0      104000.0
# Warwickshire               537500      440000.0         85000.0      149000.0
# East Sussex                514500      449000.0         94000.0       79000.0
# Bradford                   511400      449000.0         96000.0      147000.0
# Leicestershire             649300      459000.0        122000.0       28000.0
# Gloucestershire            589100      459000.0         49000.0       93000.0
# Worcestershire             559300      470000.0        128000.0      112000.0
# North Yorkshire            604100      489000.0         57000.0      141000.0
# Lincolnshire               697000      491000.0        117000.0       61000.0
# Nottinghamshire            782400      529000.0        134000.0      126000.0
# Leeds                      793800      550000.0        119000.0      172000.0
# Cambridgeshire             613200      551000.0        149000.0       10000.0
# Suffolk                    720600      559000.0        167000.0      113000.0
# Oxfordshire                644600      559000.0        100000.0      254000.0
# Staffordshire              830300      561000.0        158000.0      173000.0
# Derbyshire                 760200      580000.0        157000.0      112000.0
# Devon                      750800      580000.0         76000.0       86000.0
# Northamptonshire           687000      590000.0        234000.0       79000.0
# Norfolk                    856800      619000.0        142000.0      139000.0
# West Sussex                796700      700000.0        175000.0      227000.0
# Lancashire                1166300      800000.0        180000.0      292000.0
# Birmingham                1036800      831000.0         64000.0      272000.0
# Hertfordshire             1110400      890000.0        239000.0      246000.0
# Surrey                    1123100     1010000.0        219000.0      254000.0
# Essex                     1404000     1070000.0        297000.0      270000.0
# Hampshire                 1292900     1120000.0        187000.0      253000.0
# Kent                      1427500     1170000.0        278000.0      333000.0
#
#                          Motorcycle_Safety  Drink_Drive_Campaigns  \
# local_authority_area
# City of London                      6000.0                20000.0
# Rutland                             8000.0                14000.0
# Darlington                          3000.0                12000.0
# Hartlepool                          7000.0                17000.0
# Bracknell Forest                    9000.0                 4000.0
# Blackburn with Darwen              13000.0                21000.0
# Blackpool                           9000.0                28000.0
# Halton                              7000.0                21000.0
# Poole                              15000.0                38000.0
# Middlesbrough                      10000.0                17000.0
# Wokingham                          13000.0                19000.0
# North East Lincolnshire             7000.0                32000.0
# Reading                            10000.0                22000.0
# Slough                             16000.0                27000.0
# Telford and Wrekin                  9000.0                49000.0
# Windsor and Maidenhead             13000.0                11000.0
# Southend on Sea                     3000.0                30000.0
# Redcar and Cleveland                5000.0                19000.0
# Thurrock                           31000.0                18000.0
# Herefordshire                      13000.0                42000.0
# Knowsley                           13000.0                32000.0
# Isle of Wight                       9000.0                24000.0
# Hammersmith and Fulham             13000.0                36000.0
# Torbay                             15000.0                16000.0
# Kensington and Chelsea             10000.0                20000.0
# Bournemouth                        17000.0                39000.0
# Richmond-upon-Thames               16000.0                29000.0
# Peterborough                       11000.0                22000.0
# Bedford                            17000.0                 8000.0
# South Tyneside                     17000.0                35000.0
# ...                                    ...                    ...
# Cornwall                           10000.0                20000.0
# Sheffield                          20000.0                83000.0
# Manchester                         55000.0               107000.0
# Somerset                           36000.0                60000.0
# Warwickshire                       53000.0                64000.0
# East Sussex                        54000.0               110000.0
# Bradford                           18000.0               118000.0
# Leicestershire                     67000.0               139000.0
# Gloucestershire                    20000.0               139000.0
# Worcestershire                     57000.0                76000.0
# North Yorkshire                    11000.0               109000.0
# Lincolnshire                       45000.0               151000.0
# Nottinghamshire                    70000.0               166000.0
# Leeds                              22000.0               163000.0
# Cambridgeshire                     84000.0               214000.0
# Suffolk                            41000.0               142000.0
# Oxfordshire                        61000.0                 3000.0
# Staffordshire                      35000.0                99000.0
# Derbyshire                         38000.0               134000.0
# Devon                              88000.0               178000.0
# Northamptonshire                   87000.0                34000.0
# Norfolk                            98000.0               112000.0
# West Sussex                        63000.0                69000.0
# Lancashire                         41000.0               163000.0
# Birmingham                        130000.0               126000.0
# Hertfordshire                     102000.0               180000.0
# Surrey                             49000.0               340000.0
# Essex                              47000.0               284000.0
# Hampshire                         122000.0               266000.0
# Kent                               84000.0               291000.0
#
#                          Promote_Cycling  Promote_Car_Sharing  \
# local_authority_area
# City of London                    2000.0               1000.0
# Rutland                           5000.0               2000.0
# Darlington                       10000.0               3000.0
# Hartlepool                        7000.0               7000.0
# Bracknell Forest                 13000.0               4000.0
# Blackburn with Darwen            18000.0               8000.0
# Blackpool                        10000.0               9000.0
# Halton                           10000.0              10000.0
# Poole                             6000.0               5000.0
# Middlesbrough                    13000.0               9000.0
# Wokingham                        10000.0               6000.0
# North East Lincolnshire          25000.0               7000.0
# Reading                           6000.0               9000.0
# Slough                           15000.0              22000.0
# Telford and Wrekin               26000.0               8000.0
# Windsor and Maidenhead           12000.0               4000.0
# Southend on Sea                   9000.0              10000.0
# Redcar and Cleveland             13000.0              13000.0
# Thurrock                         11000.0               3000.0
# Herefordshire                     6000.0               4000.0
# Knowsley                         21000.0               4000.0
# Isle of Wight                    22000.0               8000.0
# Hammersmith and Fulham           14000.0               4000.0
# Torbay                           16000.0              10000.0
# Kensington and Chelsea           19000.0               6000.0
# Bournemouth                       7000.0               6000.0
# Richmond-upon-Thames             12000.0              10000.0
# Peterborough                     19000.0               7000.0
# Bedford                           3000.0              13000.0
# South Tyneside                    5000.0              10000.0
# ...                                  ...                  ...
# Cornwall                         63000.0              34000.0
# Sheffield                        27000.0              39000.0
# Manchester                       28000.0              31000.0
# Somerset                         61000.0              47000.0
# Warwickshire                     48000.0              41000.0
# East Sussex                      84000.0              28000.0
# Bradford                         48000.0              22000.0
# Leicestershire                   26000.0              77000.0
# Gloucestershire                 115000.0              43000.0
# Worcestershire                   67000.0              30000.0
# North Yorkshire                 108000.0              63000.0
# Lincolnshire                     77000.0              40000.0
# Nottinghamshire                  13000.0              20000.0
# Leeds                            63000.0              11000.0
# Cambridgeshire                   63000.0              31000.0
# Suffolk                          43000.0              53000.0
# Oxfordshire                     107000.0              34000.0
# Staffordshire                    60000.0              36000.0
# Derbyshire                       78000.0              61000.0
# Devon                           102000.0              50000.0
# Northamptonshire                 71000.0              85000.0
# Norfolk                          87000.0              41000.0
# West Sussex                      95000.0              71000.0
# Lancashire                       33000.0              91000.0
# Birmingham                      140000.0              99000.0
# Hertfordshire                    43000.0              80000.0
# Surrey                          103000.0              45000.0
# Essex                            75000.0              97000.0
# Hampshire                       203000.0              89000.0
# Kent                            121000.0              63000.0
#
#                             local_authority_type  2008_KSI_pht
# local_authority_area
# City of London                      other_london    451.327434
# Rutland                        unitary_authority     78.740157
# Darlington                     unitary_authority     33.966034
# Hartlepool                     unitary_authority     31.938326
# Bracknell Forest               unitary_authority     18.421053
# Blackburn with Darwen          unitary_authority     47.345768
# Blackpool                      unitary_authority     44.096728
# Halton                         unitary_authority     49.789030
# Poole                          unitary_authority     44.776119
# Middlesbrough                  unitary_authority     33.547466
# Wokingham                      unitary_authority     28.804008
# North East Lincolnshire        unitary_authority     64.885496
# Reading                        unitary_authority     30.831099
# Slough                         unitary_authority     45.310016
# Telford and Wrekin             unitary_authority     25.974026
# Windsor and Maidenhead         unitary_authority     47.988709
# Southend on Sea                unitary_authority     37.400368
# Redcar and Cleveland           unitary_authority     42.089985
# Thurrock                       unitary_authority     48.969072
# Herefordshire                  unitary_authority     51.926298
# Knowsley                    metropolitan_borough     38.076152
# Isle of Wight                  unitary_authority     69.900143
# Hammersmith and Fulham            london_borough     55.753262
# Torbay                         unitary_authority     26.865672
# Kensington and Chelsea            london_borough     66.043250
# Bournemouth                    unitary_authority     48.602673
# Richmond-upon-Thames              london_borough     34.188034
# Peterborough                   unitary_authority     59.481743
# Bedford                        unitary_authority     50.922979
# South Tyneside              metropolitan_borough     27.080581
# ...                                          ...           ...
# Cornwall                       unitary_authority     39.493575
# Sheffield                   metropolitan_borough     39.088551
# Manchester                  metropolitan_borough     40.152156
# Somerset                 non_metropolitan_county     52.270126
# Warwickshire             non_metropolitan_county     65.266317
# East Sussex              non_metropolitan_county     77.871258
# Bradford                    metropolitan_borough     54.646988
# Leicestershire           non_metropolitan_county     39.438815
# Gloucestershire          non_metropolitan_county     44.182873
# Worcestershire           non_metropolitan_county     44.840627
# North Yorkshire          non_metropolitan_county     90.311710
# Lincolnshire             non_metropolitan_county     48.447384
# Nottinghamshire          non_metropolitan_county     62.071641
# Leeds                       metropolitan_borough     47.606827
# Cambridgeshire           non_metropolitan_county     61.938062
# Suffolk                  non_metropolitan_county     52.350127
# Oxfordshire              non_metropolitan_county     53.973249
# Staffordshire            non_metropolitan_county     34.582830
# Derbyshire               non_metropolitan_county     56.061206
# Devon                    non_metropolitan_county     35.886449
# Northamptonshire         non_metropolitan_county     64.045936
# Norfolk                  non_metropolitan_county     45.792517
# West Sussex              non_metropolitan_county     61.501395
# Lancashire               non_metropolitan_county     68.749464
# Birmingham                  metropolitan_borough     42.189953
# Hertfordshire            non_metropolitan_county     42.347080
# Surrey                   non_metropolitan_county     47.969474
# Essex                    non_metropolitan_county     50.882883
# Hampshire                non_metropolitan_county     45.730757
# Kent                     non_metropolitan_county     44.731398
#
# [151 rows x 15 columns]

# %% [markdown]
# ... or by filling the NaN values with zero (no money spent):

# %%
df = df.fillna(value=0)
df.loc['Heathrow Airport']
# Out:
# 2008_KSI                            5
# 2009_KSI                            2
# 2010_KSI                            3
# 2008_pop                            0
# 2009_pop                            0
# 2010_pop                            0
# Total_Budget                        0
# Cyclist_Safety                      0
# Child_Safety                        0
# Motorcycle_Safety                   0
# Drink_Drive_Campaigns               0
# Promote_Cycling                     0
# Promote_Car_Sharing                 0
# local_authority_type     other_london
# 2008_KSI_pht                      inf
# Name: Heathrow Airport, dtype: object

# %% [markdown]
# Finally, let's remove the column we added and save the file:

# %%
df = df.drop(['2008_KSI_pht'],axis=1)
df.head()
# Out:
#                       2008_KSI  2009_KSI  2010_KSI  2008_pop  2009_pop  \
# local_authority_area
# City of London              51        52        48     11300     11500
# Rutland                     30        25        31     38100     38400
# Darlington                  34        27        27    100100    100400
# Hartlepool                  29        24        21     90800     90900
# Bracknell Forest            21        14        10    114000    115100
#
#                       2010_pop  Total_Budget  Cyclist_Safety  Child_Safety  \
# local_authority_area
# City of London           11700       50000.0         12000.0        9000.0
# Rutland                  38400       51000.0         17000.0        5000.0
# Darlington              100500       79000.0         18000.0       33000.0
# Hartlepool               91300       89000.0         37000.0       14000.0
# Bracknell Forest        116200       90000.0         35000.0       25000.0
#
#                       Motorcycle_Safety  Drink_Drive_Campaigns  \
# local_authority_area
# City of London                   6000.0                20000.0
# Rutland                          8000.0                14000.0
# Darlington                       3000.0                12000.0
# Hartlepool                       7000.0                17000.0
# Bracknell Forest                 9000.0                 4000.0
#
#                       Promote_Cycling  Promote_Car_Sharing  \
# local_authority_area
# City of London                 2000.0               1000.0
# Rutland                        5000.0               2000.0
# Darlington                    10000.0               3000.0
# Hartlepool                     7000.0               7000.0
# Bracknell Forest              13000.0               4000.0
#
#                      local_authority_type
# local_authority_area
# City of London               other_london
# Rutland                 unitary_authority
# Darlington              unitary_authority
# Hartlepool              unitary_authority
# Bracknell Forest        unitary_authority

# %%
df.to_csv('new_road_safety_data.csv')

# %% [markdown]
# For more information, see the 10-Minute Pandas Tutorial:
#
# https://pandas.pydata.org/pandas-docs/stable/10min.html
